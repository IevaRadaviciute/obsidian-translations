# %% [markdown]
# <a href="https://colab.research.google.com/github/IevaRadaviciute/obsidian-translations/blob/master/Python_Lab_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Programavimo įvado pratybos
#
# - Python komandoms prisiminti: ``https://www.w3schools.com/python/``
# - Naudingos Powershell komandos:
#
#     - `ls` - pažiūrėti katalogo turinį
#
#     - `md` - sukurti naują katalogą
#
#     - `cd` - pereiti į katalogą / iš katalogo
#
#     - `ni p5.py` - sukuria naują bylą vardu `p5.py`
#
#     - `python p5.py` - kompiliuoja Python programą

# %% [markdown]
# Šio darbo tikslas - išmokti naudotis pandas biblioteka ir pagilinti grafikų piešimo įgūdžius. Žinių pagilinimui, rekomenduojame atliktį šį DataCamp kursą:
#
# [Data Manipulation with pandas](https://app.datacamp.com/learn/courses/data-manipulation-with-pandas)

# %% [markdown]
# ## A1
#
# Sukurkite Pandas Series vardu `temperaturos` pasinaudodami pateiktu sąrašu:
#
# `[25, 28, 22, 30, 27]`
#
# Atspausdinkite:
# - visą Series objektą.
# - duomenų tipą `dtype`.
# - eilučių indeksų vertes`index`.
# - trečią Series elementą.
# - atspausdinkite pirmas tris Series vertes.

# %%
import pandas as pd
temperaturos = pd.Series([25, 28, 22, 30, 27])

print(serija.values)
print(serija.dtype)
print(serija.index)
print(serija[2])
print(serija)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-718701750.py in <cell line: 0>()
#       2 temperaturos = pd.Series([25, 28, 22, 30, 27])
#       3
# ----> 4 print(serija.values)
#       5 print(serija.dtype)
#       6 print(serija.index)
#
# NameError: name 'serija' is not defined

# %% [markdown]
# ## A2
# Pirmoje užduotyje sukurto Series objekto indeksai (eilučių pavadinimai) yra skaičiai nuo 0 iki n.
#
# Pakeiskite juos į valandas (pvz. 11, 12, 13, 14, 15).
#
# - Atspausdinkite 12-tos valandos temperatūrą
# - Pakeiskite jos vertę į 29
# - Atspausdinkite visą Series objektą.

# %% [markdown]
# ## A3
# Sukurkite DataFrame objektą kuriame būtų prieš tai užduotyse sukurta temperatūrų Series (turite gauti DataFrame kuriame yra vienas stulpelis).
#
# Pateikite stulpelio pavadinima "`temp_c`".
#
# Atspausdinkite DataFrame stulpelį `temp_c`.
#
# Užuomina:
# Tokiu atveju DataFrame reikia kurti pasitelkiant žodyną `{stulpelio_pav: Series_objektas}`

# %% [markdown]
# ## A4
# Sukurkite naują stulpelį, pavadinimu `temp_f`, kuriame būtų pirmojo stulpelio temperatūrų vertės (laipsniais Celsijaus) apskaičiuotos [Farenheito skalėje](https://en.wikipedia.org/wiki/Fahrenheit).
#
# Suapvalinkite `temp_f` stulpelio vertes iki dviejų skaičių po kablelio. Pasinaudokite [pandas.DataFrame.round()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.round.html) funkcija.
#
# Užuomina: sintaksė yra `df[stulpelis] = df[stulpelis].round(sk_po_kablelio)`
#
# Atspausdinkite:
# - `temp_f` stulpelį.
# - 13 valandos temperatūrą Celsijaus ir Fahrenheito skalėse:
# ```
# 13 valandą buvo XXX temp C, kas atitinka YYY temp F.
# ```

# %% [markdown]
# ## A5
# Sukurkite naują sąrašą, kuriame būtų kritulių kiekis milimetrais.
#
# Pridėkite prie ketvirtojoje užduotyje sukurto DataFrame kaip naują stulpelį, pavadinimu `krituliai`.
#
# Atspausdinkite:
# - visą lentelę (DataFrame)
# - turimo DataFrame stulpelių pavadinimus
# - jų duomenų tipus
# - visos lentelės (DataFrame) formą (shape)

# %% [markdown]
# ## A6
# Atsidarykite ir peržiūrėkite failą `ceph.csv`.
#
# Tai yra standartinis failas sugeneruotas [Vizier Astronomical Catalogue Database](https://vizier.cds.unistra.fr/viz-bin/VizieR) sistemos. Joje galima rasti įvairių astronominių tyrimų duomenų katalogus.
#
# Šiame specifiniame kataloge pateikti [cefeidžių](https://en.wikipedia.org/wiki/Cepheid_variable) stebėjimų ir analizės duomneys. Cefeidės yra kintamosios žvaigždės, kurių kitimas ir stebimas ryškis yra glaudžiai susiję, ir jos kartais netgi yra vadinamos "standartais" nustatinėjant atstumus kosmose.
#
# Failo pradžioje pateikta papildoma informacija, apie lentelę (eilutės pažymėtos komentaro simboliu `#`). Stulpelių pavadinimus rasite 56-toje eilutėje.
#
# Nuskaitykite failą į Pandas DataFrame pasinaudodami `pandas.read_csv()` funkcija.
#
# Atkreipkite dėmesį:
# - Kokiais simboliais atskirti stulpeliai (`sep`).
# - Kiek eilučių praleisti nuo viršaus (nurodykite arba skaičių, arba komentaro simbolį)
#
# Atspausdinkite nuskaitytą lentelę.
#
# Užuomina:
# Kadangi lentelėje yra daug tuščių tarpų, nuskaitant lentelę pridėkite parametrą `skipinitialspace=True` - tai automatiškai panaikins visus papildomus tarpus kurie yra prieš ir po stulpelių atskyrimo simbolius.

# %% [markdown]
# ## A7
#
# Stulpelyje `Vmag` yra pateikti cefeidžių [regimieji ryškiai](https://en.wikipedia.org/wiki/Apparent_magnitude).
#
# Matomą objektų ryškumą įtakoja bent keletas veiksnių, pvz. atstumas, arba vadinamasis [parausvėjimas](https://en.wikipedia.org/wiki/Extinction_(astronomy) - koeficientas, nusakantis šviesos skaidą (B-V color excess). Ši pataisa reikalinga dėl to, kad, sklisdama tarpžvaigždine erdve, šviesa yra sklaidoma dulkių. Panašiai kaip ir Žemės
# atmosferoje, trumpesnės bangos sklaidomos labiau nei ilgesnės, taigi išsklaidyta šviesa atrodo raudonesnė. Parausvėjimo vertė pateikta stulpelyje `E(B-V)`.
#
# Apskaičiuokite pakoreguotą matomąjį ryškį `Vmag_corr` (įrašykite kaip naują stulpelį):
#
# $V_{mag\_corr} = V_{mag} - 3.1\cdot E(B-V)$
#
# Atvaizduokite naujai apskaičiuoto stulpelio `Vmag_corr` histogramą grafike. Turite gauti panašų [grafiką](https://arnas.tfai.vu.lt/examples/hist.png).

# %% [markdown]
# ## A8
#
# Turėdami `Vmag_corr` ir cefeidės kitimo periodą (kurį galime nustatyti stebėjimais), galime įvertinti jos [absoliutinį ryškį](https://en.wikipedia.org/wiki/Absolute_magnitude) - tai objekto ryškis, kokį matytume, jei jis būtų 10 parsekų atsumu nuo mūsų ($1 pc = 3.26 ly$). Tai tarsi ryškių standartizavimas. Cefeidės absoliutinis ryškis, žinant jos pulsavimo (kitimo) periodą apskaičiuojamas pagal formulę:
#
# $M_V = -2.5 \cdot log_{10}(P) - 1.5$, kur
#
# $M_V$ - absoliutinis ryškis
#
# $P$ - kitimo periodas dienomis (stulpelis `Per`)
#
# Sukurkite naują stulpelį ir jam priskirkite apskaičiuojas $M_V$ vertes. Atspausdinkite naujai sukurtą stulpelį.
#
# Atvaizduokite grafiškai (`scatter`) kaip $M_V$ (y ašis) priklauso nuo $P$ (x ašis). $M_V$ ašį apverskite.
#
# Turite gauti panašų [grafiką](https://arnas.tfai.vu.lt/examples/cepheids.png)

# %% [markdown]
# ## A9
#
# Žinant absoliutinį ryškį (objekto ryškumą standartiniame nuotolyje) bei jo regimąjį ryškį (koks ryškus jis atrodo iš tiesų), mes galime apskaičiuoti jo atstumą:
#
# $M_V = m_V - 5 \cdot log_{10}(d_{pc})+5 $, kur
#
# $M_V$ - absoliutinis ryškis (apskaičiuotas A8 užduotyje)
#
# $m_V$ - regimasis ryškis (apskaičiuotas A7 užduotyje)
#
# $d_{pc}$ - atstumas parsekais
#
# Sukurkite naują stulpelį, kuriame būtų apskaičiuotas atstumas parsekais.

# %% [markdown]
# ## A10
#
# Apskaičiavome atstumą iš žavigždės ryškio pokyčių.
#
# Yra kitas nepriklausomas būdas įvertinti atstumą - iš objekto [paralakso](https://en.wikipedia.org/wiki/Parallax) vertės. Jis yra pateiktas `plx` stulpelyje. Jis matuojamas [$mas$](https://en.wikipedia.org/wiki/Minute_and_second_of_arc) - tūkstantosiomis kampo sekundėmis.
#
# Atstumą galime suskaičiuoti:
#
# $d_{plx} = \frac{1}{plx}$, kur
#
# $d_{plx}$ - atstumas
#
# $plx$ - paralakso vertė.
#
# Apskaičiuokite atstumą gaunamą iš paralakso vertės.
#
# Kadangi paralakso vertė patekta tūkstantosiomis kampo sekundėmis, jūsų gautas atstumas bus kiloparsekais ($kpc$), kai tuo tarpu A9 užduotyje gautas atstumas yra parsekais ($pc$). Nepamirškite suvienodinti vienetų.
#
# Atvaizduokite grafiškai abu atstumus. Taip pat grafike atvaizudokite ir 1:1 liniją. Turrite gauti panašų [grafiką](https://arnas.tfai.vu.lt/examples/distances.png).
